# %% [markdown]
# # Prepare data for loading

# %%
import numpy as np
import os
import cv2
from typing import Dict

DATA_ROOT_DIR = "data"
BENCHMARK_DIR = "saved_benchmarks"

# %%
# Every file in data will be considered and preprocessed
file_names = os.listdir(f"{DATA_ROOT_DIR}/{BENCHMARK_DIR}/")

# %%
file_names = [f for f in file_names if "Breakout" in f]

# %%
def split_data(data: Dict[str, np.ndarray]) -> Dict[str, np.ndarray]:
    """Splits the data into episodes."""
    episode_ends = np.argwhere(data['dones']).squeeze()
    episodes = {}
    for name, data_item in data.items():
        if data_item.shape:
            episodes[name] = np.split(data_item, episode_ends)
        else:
            episodes[name] = data_item

    return episodes

# %%
def encode_video(renders: np.ndarray, path: str) -> None:
    """
    Encodes renders of shape [n_frames, height, width, 3] into a .mp4 video and
    saves it at path.
    """
    # Create video in H264 format
    out = cv2.VideoWriter(
        f"{path}.mp4",
        cv2.VideoWriter_fourcc(*"avc1"),
        24,
        (renders.shape[2], renders.shape[1]),
    )
    for render in renders:
        out.write(render)
    out.release()

# %%
for file_name in file_names:
    dir_name = f"{DATA_ROOT_DIR}/episodes/{os.path.splitext(file_name)[0]}"
    if not os.path.isdir(dir_name):
        os.makedirs(dir_name, exist_ok=True)
    data = np.load(f"{DATA_ROOT_DIR}/{BENCHMARK_DIR}/{file_name}", allow_pickle=True)
    episode_data = split_data(data)
    # Save as single episodes with an incrementing index
    for episode_idx, _ in enumerate(episode_data['dones']):
        save_episode = {}
        for name, _ in episode_data.items():
            print(name)
            if name == 'additional_metrics':
                continue
            save_episode[name] = episode_data[name][episode_idx]
        os.makedirs(f"{DATA_ROOT_DIR}/rewards/{os.path.splitext(file_name)[0]}", exist_ok=True)
        np.savez(f"{dir_name}/benchmark_{episode_idx}.npz", **save_episode)
# Out:
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics
# obs
# rewards
# dones
# actions
# renders
# infos
# feature_extractor_buffer
# probs
# episode_rewards
# episode_lengths
# additional_metrics

# %%
for file_name in file_names:
    data = np.load(f"{DATA_ROOT_DIR}/{BENCHMARK_DIR}/{file_name}", allow_pickle=True)
    episode_data = split_data(data)
    for episode_idx, renders in enumerate(episode_data['renders']):
        dir_name = f"{DATA_ROOT_DIR}/renders/{os.path.splitext(file_name)[0]}"
        if not os.path.isdir(dir_name):
            os.makedirs(dir_name)
        encode_video(renders, f"{dir_name}/{episode_idx}")
    
    # Free memory
    del data
    del episode_data
# Out:
# [h264_videotoolbox @ 0x7fed4520f200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4520f200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@495.676] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@495.679] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:22.897 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44239000] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44239000] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@495.758] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@495.758] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:22.909 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44241600] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44241600] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@495.763] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@495.763] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:22.914 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4683c600] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4683c600] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@495.768] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@495.768] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:22.919 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44242c00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44242c00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@495.773] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@495.773] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:22.925 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44244600] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44244600] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@495.779] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@495.779] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:22.930 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44245200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44245200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@495.786] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@495.786] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:22.938 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44246c00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44246c00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@495
global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:24.916 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a53e00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a53e00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@497.770] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@497.770] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:24.920 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a55200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a55200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@497.774] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@497.774] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:24.924 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4425e200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4425e200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@497.778] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@497.778] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:24.929 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a56c00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a56c00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@497.783] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@497.783] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:24.933 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed461f3c00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed461f3c00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# ...
# [ERROR:0@505.566] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.717 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed46221200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed46221200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.572] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.572] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.723 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a91200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a91200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.578] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.578] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.729 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4523de00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4523de00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.583] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.583] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.734 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a92400] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a92400] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.587] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.587] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.738 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed46221e00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed46221e00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.592] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.592] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.743 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a93600] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a93600] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.597] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.597] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.747 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4525e200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4525e200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.601] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.601] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.752 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4622c400] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4622c400] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.606] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.606] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.756 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44289200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44289200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.610] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.610] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.761 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a94200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a94200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.615] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.615] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.766 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a95600] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a95600] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.620] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.620] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.770 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4622d600] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4622d600] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.624] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.624] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.775 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44284c00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44284c00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.628] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.628] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.779 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4622e200] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4622e200] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.633] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.633] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.784 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4525ee00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4525ee00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.638] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.638] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.790 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed45260e00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed45260e00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.644] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.645] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.796 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44286c00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44286c00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.650] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.650] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.802 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed44a97000] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed44a97000] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.656] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.656] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.807 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed4622fc00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed4622fc00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.661] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.661] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.812 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed46231000] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed46231000] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.666] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.666] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.817 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed45261a00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed45261a00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.671] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.671] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.822 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed45263400] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed45263400] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.676] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.676] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.827 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed42850600] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed42850600] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.681] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.681] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.832 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save
# [h264_videotoolbox @ 0x7fed45269c00] Error: cannot create compression session: -12903
# [h264_videotoolbox @ 0x7fed45269c00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# [ERROR:0@505.686] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2822) open Could not open codec h264_videotoolbox, error: Unspecified error
# [ERROR:0@505.686] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp (2839) open VIDEOIO/FFMPEG: Failed to initialize VideoWriter
# 2023-07-03 10:57:32.837 Python[55148:4268933] AVF: AVAssetWriter status: Cannot Save

# %%
os.makedirs(f"{DATA_ROOT_DIR}/rewards", exist_ok=True)

# Write thumbnails#
for file_name in file_names:
    data = np.load(f"{DATA_ROOT_DIR}/{BENCHMARK_DIR}/{file_name}", allow_pickle=True)
    episode_data = split_data(data)
    for episode_idx, renders in enumerate(episode_data['renders']):
        dir_name = f"{DATA_ROOT_DIR}/thumbnails/{os.path.splitext(file_name)[0]}"
        if not os.path.isdir(dir_name):
            os.makedirs(dir_name)
        
        # Save first rame of the episode, first convert to BGR
        save_image = cv2.cvtColor(renders[0], cv2.COLOR_RGB2BGR)
        cv2.imwrite(f"{dir_name}/{episode_idx}.jpg", save_image)

        # Save step rewards to "rewards_{}.npy" arrays
        os.makedirs(f"{DATA_ROOT_DIR}/rewards/{os.path.splitext(file_name)[0]}", exist_ok=True)
        np.save(f"{DATA_ROOT_DIR}/rewards/{os.path.splitext(file_name)[0]}/rewards_{episode_idx}.npy", np.cumsum(episode_data['rewards'][episode_idx]))

    # Free memory
    del data
    del episode_data
