# %%
import numpy as np
import os
import matplotlib.pyplot as plt

os.listdir("data/saved_benchmarks/")
# Out:
# ['BreakoutNoFrameskip-v4_trained_1_6000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_7000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_4000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_8000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_10000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_1000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_3000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_2000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_5000000.npz',
#  'BreakoutNoFrameskip-v4_trained_1_9000000.npz']

# %%
data = np.load("data/saved_benchmarks/" + os.listdir("data/saved_benchmarks/")[0], allow_pickle=True)

# %%
for k, v in data.items():
    print(k, v.shape)
# Out:
# obs (6831, 84, 84, 4)
# rewards (6831,)
# dones (6831,)
# actions (6831,)
# renders (6831, 210, 160, 3)
# infos (6831,)
# feature_extractor_buffer (6831, 512)
# probs (6831, 4)
# episode_rewards (5,)
# episode_lengths (5,)
# additional_metrics ()

# %%
renders = data["renders"]
for i in range(renders.shape[0]):
    plt.imshow(renders[i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 renders = data["renders"]
#       2 for i in range(renders.shape[0]):
# ----> 3     plt.imshow(renders[i])
#       4     plt.show()
#
# File ~/miniconda3/envs/rlw/lib/python3.8/site-packages/matplotlib/pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
# ...
